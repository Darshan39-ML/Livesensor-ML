# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/darshan39/miniconda3/envs/new/lib/python3.12/site-packages (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string =  "mongodb+srv://darshan39:Krishn_4@cluster0.puwtldn.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db= client["liveclass"]

# %%
collection=db["mongoclass"]

# %%
data = {
    "name": "prince katiyar",
    "age": 2,
    "email": "princekatiyar98643343@gmail.com"
}

# %%
collection.insert_one(data)

# %%
cursor=collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('68ce5318a357030110692d12'), 'name': 'Darshan', 'age': 21, 'email': 'darshanganorkar444@gmail.com'}
# {'_id': ObjectId('68cfc8f35d7f185688bbfe0f'), 'name': 'darshan', 'age': 21, 'email': 'darshanganorkar8@gmail.com'}
# {'_id': ObjectId('68d00a912f50fad673766372'), 'name': 'nitin', 'age': 28, 'email': 'nitin298@gmail.com'}
# {'_id': ObjectId('68d556b28d154604e07e647b'), 'name': 'prince katiyar', 'age': 2, 'email': 'princekatiyar98643343@gmail.com'}
# {'_id': ObjectId('68d93f316ab1e616632b1a9b'), 'name': 'prince katiyar', 'age': 2, 'email': 'princekatiyar98643343@gmail.com'}
