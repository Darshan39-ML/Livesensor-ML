# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
# NOTE: Do NOT hardcode credentials here. The original cell contained an exposed URI and has been removed.
# Secure approach: load MONGODB_URI from environment or a local .env file (see .env.example).
from dotenv import load_dotenv
import os
from pymongo import MongoClient

load_dotenv()  # optional: loads .env in current directory
MONGODB_URI = os.environ.get('MONGODB_URI')

if not MONGODB_URI:
    raise RuntimeError('MONGODB_URI not set. Copy .env.example -> .env and set the variable, or export it in your shell.')

client = MongoClient(MONGODB_URI)
try:
    print('Connected. Databases:', client.list_database_names())
except Exception as e:
    print('Connection failed:', e)

# %%
client = MongoClient(connection_strings)

# %%
db = client["mongoclass"]
